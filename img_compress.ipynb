# %%
# !pip install pillow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 15.4 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from PIL import Image
import os

input_img_path="assets/img/cde_sem1/8_21.png"
output_img_path="assets/img/cde_sem1/8_21_th.webp"
img = Image.open(input_img_path)
img.save(output_img_path, optimize=True, quality=0)
# img.save("output.webp", optimize=True, quality=85)
print (os.path.getsize(input_img_path)/ (1024 * 1024),os.path.getsize(output_img_path)/ (1024 * 1024))
# Out:
# 0.14998245239257812 0.01184844970703125
